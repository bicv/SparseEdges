# %% [markdown]
# # SparseEdges : including prior information

# %% [markdown]
# Using prior information in the edge extraction
#
#
# Table of content
#
# * [Prior on first-order distribution of orientations](#Prior-on-first-order-distribution-of-orientations)
# * [Prior on second-order distribution of edge co-occurences](#Prior-on-second-order-distribution-of-orientations)
# * [Application to segmentation](#Application-to-segmentation)

# %% [markdown]
# ## Initialization

# %%
import matplotlib
#matplotlib.rcParams.update({'font.size': 18, 'font.family': 'STIXGeneral', 'mathtext.fontset': 'stix'})
matplotlib.rcParams.update({'text.usetex': False})
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
import matplotlib.pyplot as plt

import numpy as np
np.set_printoptions(precision=4)#, suppress=True)
# http://ipython.org/ipython-doc/stable/config/extensions/autoreload.html
#%load_ext autoreload
#%autoreload 2

# where should we store the figures generated by this notebook
figpath = None
figpath = '../../CNRS/BICV-book/BICV_INT/BICV-sparse/'
FORMATS = ['pdf', 'eps']

# %%
from NeuroTools.parameters import ParameterSet
from SLIP import Image
from LogGabor import LogGabor
from SparseEdges import SparseEdges

# %%
#! defining framework
#!-------------------
pe = ParameterSet('default_param.py')
#pe.N = 4
#pe.do_mask=False
#pe.MP_alpha=1.
#pe.do_whitening = False
im = Image(pe)
lg = LogGabor(im)
mp = SparseEdges(lg)

print 'Range of spatial frequencies: ', mp.sf_0
# Out:
# Range of spatial frequencies:  [ 0.5     0.25    0.125   0.0625  0.0312  0.0156  0.0078  0.0039]

# %%
print 'Range of angles: ', mp.theta*180./np.pi
# Out:
# Range of angles:  [-82.5 -75.  -67.5 -60.  -52.5 -45.  -37.5 -30.  -22.5 -15.   -7.5   0.
#    7.5  15.   22.5  30.   37.5  45.   52.5  60.   67.5  75.   82.5  90. ]

# %% [markdown]
# ## Prior on first-order distribution of orientations

# %% [markdown]
# First, we retrieve edges from a prior edge extraction

# %%
imageslist, edgeslist, RMSE = mp.process(exp='SparseLets', name_database='serre07_distractors')
# Out:
# INFO:SparseEdges: > computing edges for experiment SparseLets with database serre07_distractors
# INFO:SparseEdges:>>> For the class serre07_distractors, in experiment SparseLets RMSE = 0.041716

# %% [raw]
# print figpath
# !ls ../../CNRS/BICV-book/BICV_INT/BICV-sparse/

# %%
#fig, (a1, a2) = plt.subplots(1, 2)
#fig, a1 = mp.histedges_theta(edgeslist, fig=fig, a=a1)
#fig, a2 = mp.histedges_theta(edgeslist, fig=fig, a=a1)
fig_width_pt = 318.670  # Get this from LaTeX using \showthe\columnwidth
inches_per_pt = 1.0/72.27               # Convert pt to inches
fig_width = fig_width_pt*inches_per_pt  # width in inches
fig = plt.figure(figsize=(fig_width/1.618, fig_width/1.618))
ax = fig.add_subplot(111, axisbg='w', polar=True)
fig, ax = mp.histedges_theta(edgeslist, fig=fig, a=ax)
v_hist, v_theta_edges = mp.histedges_theta(edgeslist, display=False)
ax.plot((v_theta_edges[1:]+v_theta_edges[:-1])/2, np.ones_like(v_hist)*v_hist.mean(), 'r--')
ax.plot((v_theta_edges[1:]+v_theta_edges[:-1])/2+np.pi, np.ones_like(v_hist)*v_hist.mean(), 'r--')

if not(figpath==None): 
    for ext in FORMATS: fig.savefig(figpath + 'firstorder_A.' + ext)
# Out:
# -1.4398966329 1.57079632679 -1.50534647985 1.63624617374
# -1.4398966329 1.57079632679 -1.50534647985 1.63624617374

# %%
v_theta_edges[1:] - mp.theta, np.pi/mp.n_theta/2, v_hist, edgeslist[2, ...]
# Out:
# (array([ 0.1963,  0.1963,  0.1963,  0.1963,  0.1963,  0.1963,  0.1963,
#          0.1963,  0.1963,  0.1963,  0.1963,  0.1963,  0.1963,  0.1963,
#          0.1963,  0.1963,  0.1963,  0.1963,  0.1963,  0.1963,  0.1963,
#          0.1963,  0.1963,  0.1963]),
#  0.06544984694978735,
#  array([ 0.0377,  0.0379,  0.035 ,  0.0356,  0.0355,  0.0323,  0.0326,
#          0.0389,  0.0404,  0.0493,  0.0822,  0.0509,  0.0454,  0.0443,
#          0.0419,  0.036 ,  0.0325,  0.0359,  0.0328,  0.0345,  0.0378,
#          0.0447,  0.1057,  0.    ]),
#  array([[ 0.7854,  0.1309,  2.3562, ...,  1.5708,  0.1309,  0.    ],
#         [ 1.309 ,  3.0107,  0.    , ...,  1.5708,  2.8798,  0.2618],
#         [ 1.4399,  0.1309,  1.7017, ...,  1.5708,  0.    ,  0.7854],
#         ...,
#         [ 0.5236,  2.618 ,  1.7017, ...,  0.5236,  2.618 ,  3.0107],
#         [ 0.6545,  2.7489,  1.309 , ...,  0.7854,  2.4871,  0.9163],
#         [ 2.3562,  0.6545,  0.7854, ...,  0.7854,  1.8326,  1.7017]]))

# %%
edges = np.load('/Users/lolo/Dropbox/science/SparseEdges/mat/edges/prior_vanilla_serre07_distractors/Bda_art1111.jpg[0, 256, 0, 256].npy')
plt.hist(edges[2])
# Out:
# (array([  24.,   10.,   10.,    9.,   41.,   10.,   16.,   11.,   12.,  369.]),
#  array([-1.4399, -1.1388, -0.8378, -0.5367, -0.2356,  0.0654,  0.3665,
#          0.6676,  0.9687,  1.2697,  1.5708]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Now, we may use this statistics:

# %%
fig, [[B, C], [A, D]] = plt.subplots(2, 2, figsize=(fig_width, fig_width/1.618), sharex=True, subplot_kw={'axisbg':'w'})
v_hist, v_theta_edges = mp.histedges_theta(edgeslist, display=False)
v_theta_middles, v_theta_bin  = (v_theta_edges[1:]+v_theta_edges[:-1])/2, v_theta_edges[1]-v_theta_edges[0]
A.bar(v_theta_edges, np.hstack((v_hist, v_hist[-1])), alpha=.6, width=v_theta_bin)
plt.setp(A, yticklabels=[], xlim=[v_theta_edges[1], v_theta_edges[-1]], xticks=[0, np.pi/2], xticklabels=[r'$0$', r'$\pi/2$'], xlabel=r'$\theta$ (rad)', ylabel=r'$p(\theta)$')
B.step(v_theta_edges-v_theta_bin/2, np.hstack((0, np.cumsum(v_hist))), where='post')
#B.bar(v_theta_middles, np.cumsum(v_hist), alpha=.6, width=v_theta_bin)
plt.setp(B, xticks=[], xlim=[v_theta_edges[0], v_theta_edges[-1]], ylim=[0,1], yticks=[0., 0.5, 1.], ylabel=r'$P(\theta)$')
#B.text(-np.pi/2*1.65, 1.05, '(B)')
z = np.linspace(.5/pe.n_theta, 1.-.5/pe.n_theta, pe.n_theta)
theta = np.interp(z, np.hstack((0, np.cumsum(v_hist))), v_theta_edges)
C.plot(v_theta_edges, np.hstack((0, np.cumsum(v_hist))))
C.hlines(z, [-np.pi/2], theta, lw=.5)
C.vlines(theta, [0], z, lw=.5, color='r')
#C.text(-np.pi/2*1.1, 1.05, '(C)')
plt.setp(C, xlim=[v_theta_edges[0], v_theta_edges[-1]], ylim=[0,1], xticks=[], yticks=[])
D.axis('tight')
D.vlines(theta, [0], np.ones_like(z), lw=.5, color='r')
D.plot(theta, np.ones_like(z), ms='^', lw=0, color='r')
plt.setp(D, ylim=[0, 1.3], yticks=[], xlim=[v_theta_edges[1], v_theta_edges[-1]], xticks=[0, np.pi/2], xticklabels=[r'$0$', r'$\pi/2$'], xlabel=r'$\theta$ (rad)')
#D.text(-np.pi/2*1.1, 1.35, '(D)')
#plt.tight_layout()
if not(figpath==None): 
    for ext in FORMATS: fig.savefig(figpath + 'laughlin.' + ext)
# Out:
# -1.4398966329 1.57079632679 -1.37444678595 1.76714586764

# %%
print v_hist, (v_theta_edges-v_theta_bin/2)*180/np.pi
z = np.linspace(0, 1.-1./pe.n_theta, pe.n_theta)
print np.hstack((0, np.cumsum(v_hist))), np.interp(z, np.hstack((0, np.cumsum(v_hist))), (v_theta_edges-v_theta_bin/2))*180/np.pi
# Out:
# [ 0.      0.      0.0246  0.      0.0155  0.0189  0.0151  0.0194  0.0924
#   0.0138  0.2909  0.04    0.0598  0.0161  0.      0.025   0.      0.      0.
#   0.      0.      0.0258  0.3427  0.    ] [ -8.2500e+01  -7.5000e+01  -6.7500e+01  -6.0000e+01  -5.2500e+01
#   -4.5000e+01  -3.7500e+01  -3.0000e+01  -2.2500e+01  -1.5000e+01
#   -7.5000e+00   3.9757e-15   7.5000e+00   1.5000e+01   2.2500e+01
#    3.0000e+01   3.7500e+01   4.5000e+01   5.2500e+01   6.0000e+01
#    6.7500e+01   7.5000e+01   8.2500e+01   9.0000e+01   9.7500e+01]
# [ 0.      0.      0.      0.0246  0.0246  0.0401  0.059   0.0741  0.0936
#   0.1859  0.1998  0.4907  0.5306  0.5905  0.6065  0.6065  0.6315  0.6315
#   0.6315  0.6315  0.6315  0.6315  0.6573  1.      1.    ] [-67.5    -44.3947 -26.4475 -19.9473 -16.5646  -7.2795  -6.2052  -5.1309
#   -4.0566  -2.9823  -1.908   -0.8337   1.7509   8.8828  14.1068  35.5495
#   82.7047  83.6166  84.5285  85.4404  86.3524  87.2643  88.1762  89.0881]

# %%
# %%writefile experiment_fig-firstorder.py
import __init__
import numpy as np
from NeuroTools.parameters import ParameterSet
from SLIP import Image
from LogGabor import LogGabor
from SparseEdges import SparseEdges

pe = ParameterSet('default_param.py')
im = Image(pe)
lg = LogGabor(im)
mp = SparseEdges(lg)

pe.seed = 42 # this ensures that all image lists are the same for the different experiments

for name_database in ['serre07_distractors', 'laboratory']:
    # control experiment
    imageslist, edgeslist, RMSE = mp.process(exp='prior_vanilla', name_database=name_database)
    imageslist, edgeslist_noise, RMSE = mp.process(exp='prior_vanilla_noise', name_database=name_database, noise=pe.noise)

    try:
        # first-order prior
        v_hist, v_theta_edges = mp.histedges_theta(edgeslist, display=False)
        v_theta_middles, v_theta_bin  = (v_theta_edges[1:]+v_theta_edges[:-1])/2, v_theta_edges[1]-v_theta_edges[0]

        z = np.linspace(0, 1.-1./pe.n_theta, pe.n_theta)

        mp.theta = np.interp(z, np.hstack((0, np.cumsum(v_hist))), (v_theta_edges-v_theta_bin/2))

        imageslist, edgeslist, RMSE =  mp.process(exp='prior_vanilla_firstorder', name_database=name_database)
        imageslist, edgeslist, RMSE = mp.process(exp='prior_vanilla_firstorder_noise', name_database=name_database, noise=pe.noise)
    except:
        print('run again once first batches are finished ')
# Out:
# Overwriting experiment_fig-firstorder.py

# %%
# %run experiment_fig-firstorder.py
# Out:
# INFO:SparseEdges: > computing edges for experiment prior_vanilla with database serre07_distractors
# INFO:SparseEdges:>>> For the class serre07_distractors, in experiment prior_vanilla RMSE = 0.997700
# INFO:SparseEdges: > computing edges for experiment prior_vanilla_noise with database serre07_distractors
# INFO:SparseEdges:>>> For the class serre07_distractors, in experiment prior_vanilla_noise RMSE = 0.997558
# INFO:SparseEdges: > computing edges for experiment prior_vanilla with database laboratory
# INFO:SparseEdges:>>> For the class laboratory, in experiment prior_vanilla RMSE = 0.771832
# SparseEdges.py:427: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if not(edgeslist==None):
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000924
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000150
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.020842
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000635
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.005832
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000202
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.152134
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.009208
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.002761
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.031973
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.051758
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.113944
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.005093
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000338
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000000
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.001247
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000766
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000647
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.049069
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000917
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000614
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.037014
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.012867
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.197093
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.028357
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.003284
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.009900
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.009664
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.049669
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.011567
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.010291
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.004001
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.005090
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000166
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000627
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.048642
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000247
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.608250
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.001347
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.002442
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000120
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.009071
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000212
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.125661
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000709
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000278
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000570
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.066512
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000363
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.024060
# -1.4398966329 1.57079632679 -1.37444678595 1.76714586764
# run again once first batches are finished
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/lolo/Dropbox/science/SparseEdges/experiment_fig-firstorder.py in <module>()
#      15 for name_database in ['serre07_distractors', 'laboratory']:
#      16     # control experiment
# ---> 17     imageslist, edgeslist, RMSE = mp.process(exp='prior_vanilla', name_database=name_database)
#      18     imageslist, edgeslist_noise, RMSE = mp.process(exp='prior_vanilla_noise', name_database=name_database, noise=pe.noise)
#      19
#
# /Users/lolo/Dropbox/science/SparseEdges/SparseEdges.py in process(self, exp, name_database, note, noise)
#     937                 figname = os.path.join(self.pe.figpath, exp + '_proba-edgefield_chevrons_' + name_database + note + self.pe.ext)
#     938                 if not(os.path.isfile(figname)):
# --> 939                     fig, a = self.cohistedges(edgeslist, display='chevrons')
#     940                     plt.savefig(figname)
#     941                     plt.close('all')
#
# /Users/lolo/Dropbox/science/SparseEdges/SparseEdges.py in cohistedges(self, edgeslist, v_hist, prior, fig, a, symmetry, display, v_min, v_max, labels, mappable, radius, xticks, half, dolog, color, colorbar, cbar_label)
#     780                         plt.setp(a, yticklabels=['', '', ''])
#     781                 plt.grid('off')
# --> 782             plt.draw()
#     783
#     784             return fig, a
#
# /usr/local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in draw()
#     569
#     570     """
# --> 571     get_current_fig_manager().canvas.draw()
#     572
#     573
#
# /usr/local/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in draw(self)
#     467
#     468         try:
# --> 469             self.figure.draw(self.renderer)
#     470         finally:
#     471             RendererAgg.lock.release()
#
# /usr/local/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/local/lib/python2.7/site-packages/matplotlib/figure.pyc in draw(self, renderer)
#    1077         dsu.sort(key=itemgetter(0))
#    1078         for zorder, a, func, args in dsu:
# -> 1079             func(*args)
#    1080
#    1081         renderer.close_group('figure')
#
# /usr/local/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/local/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in draw(self, renderer, inframe)
#    2090
#    2091         for zorder, a in dsu:
# -> 2092             a.draw(renderer)
#    2093
#    2094         renderer.close_group('axes')
#
# /usr/local/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/local/lib/python2.7/site-packages/matplotlib/axis.pyc in draw(self, renderer, *args, **kwargs)
#    1126         self._update_label_position(ticklabelBoxes, ticklabelBoxes2)
#    1127
# -> 1128         self.label.draw(renderer)
#    1129
#    1130         self._update_offset_text_position(ticklabelBoxes, ticklabelBoxes2)
#
# /usr/local/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      57     def draw_wrapper(artist, renderer, *args, **kwargs):
#      58         before(artist, renderer)
# ---> 59         draw(artist, renderer, *args, **kwargs)
#      60         after(artist, renderer)
#      61
#
# /usr/local/lib/python2.7/site-packages/matplotlib/text.pyc in draw(self, renderer)
#     536         renderer.open_group('text', self.get_gid())
#     537
# --> 538         bbox, info, descent = self._get_layout(renderer)
#     539         trans = self.get_transform()
#     540
#
# /usr/local/lib/python2.7/site-packages/matplotlib/text.pyc in _get_layout(self, renderer)
#     318                 w, h, d = renderer.get_text_width_height_descent(clean_line,
#     319                                                         self._fontproperties,
# --> 320                                                         ismath=ismath)
#     321             else:
#     322                 w, h, d = 0, 0, 0
#
# /usr/local/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in get_text_width_height_descent(self, s, prop, ismath)
#     221             fontsize = prop.get_size_in_points()
#     222             w, h, d = texmanager.get_text_width_height_descent(s, fontsize,
# --> 223                                                                renderer=self)
#     224             return w, h, d
#     225
#
# /usr/local/lib/python2.7/site-packages/matplotlib/texmanager.pyc in get_text_width_height_descent(self, tex, fontsize, renderer)
#     671             dvi = dviread.Dvi(dvifile, 72 * dpi_fraction)
#     672             try:
# --> 673                 page = next(iter(dvi))
#     674             finally:
#     675                 dvi.close()
#
# /usr/local/lib/python2.7/site-packages/matplotlib/dviread.pyc in __iter__(self)
#      87         """
#      88         while True:
# ---> 89             have_page = self._read()
#      90             if have_page:
#      91                 yield self._output()
#
# /usr/local/lib/python2.7/site-packages/matplotlib/dviread.pyc in _read(self)
#     148         while True:
#     149             byte = ord(self.file.read(1)[0])
# --> 150             self._dispatch(byte)
#     151 #             if self.state == _dvistate.inpage:
#     152 #                 matplotlib.verbose.report(
#
# /usr/local/lib/python2.7/site-packages/matplotlib/dviread.pyc in _dispatch(self, byte)
#     236             c, s, d, a, l = [ self._arg(x) for x in (4, 4, 4, 1, 1) ]
#     237             n = self.file.read(a+l)
# --> 238             self._fnt_def(k, c, s, d, a, l, n)
#     239         elif byte == 247:
#     240             i, num, den, mag, k = [ self._arg(x) for x in (1, 4, 4, 4, 1) ]
#
# /usr/local/lib/python2.7/site-packages/matplotlib/dviread.pyc in _fnt_def(self, k, c, s, d, a, l, n)
#     404         #        (d, tfm.design_size, n)
#     405
# --> 406         vf = _vffile(n[-l:].decode('ascii'))
#     407
#     408         self.fonts[k] = DviFont(scale=s, tfm=tfm, texname=n, vf=vf)
#
# /usr/local/lib/python2.7/site-packages/matplotlib/dviread.pyc in _vffile(texname)
#     906
#     907 def _vffile(texname):
# --> 908     return _fontfile(texname, Vf, '.vf', _vfcache)
#     909
#     910
#
# /usr/local/lib/python2.7/site-packages/matplotlib/dviread.pyc in _fontfile(texname, class_, suffix, cache)
#     895     filename = find_tex_file(texname + suffix)
#     896     if filename:
# --> 897         result = class_(filename)
#     898     else:
#     899         result = None
#
# /usr/local/lib/python2.7/site-packages/matplotlib/dviread.pyc in __init__(self, filename)
#     516             self._chars = {}
#     517             self._packet_ends = None
# --> 518             self._read()
#     519         finally:
#     520             self.close()
#
# /usr/local/lib/python2.7/site-packages/matplotlib/dviread.pyc in _read(self)
#     148         while True:
#     149             byte = ord(self.file.read(1)[0])
# --> 150             self._dispatch(byte)
#     151 #             if self.state == _dvistate.inpage:
#     152 #                 matplotlib.verbose.report(
#
# /usr/local/lib/python2.7/site-packages/matplotlib/dviread.pyc in _dispatch(self, byte)
#     546             self._init_packet(pl, cc, tfm)
#     547         elif 243 <= byte <= 246:
# --> 548             Dvi._dispatch(self, byte)
#     549         elif byte == 247:       # preamble
#     550             i, k = self._arg(1), self._arg(1)
#
# /usr/local/lib/python2.7/site-packages/matplotlib/dviread.pyc in _dispatch(self, byte)
#     236             c, s, d, a, l = [ self._arg(x) for x in (4, 4, 4, 1, 1) ]
#     237             n = self.file.read(a+l)
# --> 238             self._fnt_def(k, c, s, d, a, l, n)
#     239         elif byte == 247:
#     240             i, num, den, mag, k = [ self._arg(x) for x in (1, 4, 4, 4, 1) ]
#
# /usr/local/lib/python2.7/site-packages/matplotlib/dviread.pyc in _fnt_def(self, k, *args)
#     584
#     585     def _fnt_def(self, k, *args):
# --> 586         Dvi._fnt_def(self, k, *args)
#     587         if self._first_font is None:
#     588             self._first_font = k
#
# /usr/local/lib/python2.7/site-packages/matplotlib/dviread.pyc in _fnt_def(self, k, c, s, d, a, l, n)
#     404         #        (d, tfm.design_size, n)
#     405
# --> 406         vf = _vffile(n[-l:].decode('ascii'))
#     407
#     408         self.fonts[k] = DviFont(scale=s, tfm=tfm, texname=n, vf=vf)
#
# /usr/local/lib/python2.7/site-packages/matplotlib/dviread.pyc in _vffile(texname)
#     906
#     907 def _vffile(texname):
# --> 908     return _fontfile(texname, Vf, '.vf', _vfcache)
#     909
#     910
#
# /usr/local/lib/python2.7/site-packages/matplotlib/dviread.pyc in _fontfile(texname, class_, suffix, cache)
#     893         pass
#     894
# --> 895     filename = find_tex_file(texname + suffix)
#     896     if filename:
#     897         result = class_(filename)
#
# /usr/local/lib/python2.7/site-packages/matplotlib/dviread.pyc in find_tex_file(filename, format)
#     875     pipe = subprocess.Popen(cmd, stdout=subprocess.PIPE,
#     876                             stderr=subprocess.PIPE)
# --> 877     result = pipe.communicate()[0].rstrip()
#     878     matplotlib.verbose.report('find_tex_file result: %s' % result,
#     879                               'debug')
#
# /usr/local/Cellar/python/2.7.8_2/Frameworks/Python.framework/Versions/2.7/lib/python2.7/subprocess.pyc in communicate(self, input)
#     797             return (stdout, stderr)
#     798
# --> 799         return self._communicate(input)
#     800
#     801
#
# /usr/local/Cellar/python/2.7.8_2/Frameworks/Python.framework/Versions/2.7/lib/python2.7/subprocess.pyc in _communicate(self, input)
#    1401                 stdout, stderr = self._communicate_with_poll(input)
#    1402             else:
# -> 1403                 stdout, stderr = self._communicate_with_select(input)
#    1404
#    1405             # All data exchanged.  Translate lists into strings.
#
# /usr/local/Cellar/python/2.7.8_2/Frameworks/Python.framework/Versions/2.7/lib/python2.7/subprocess.pyc in _communicate_with_select(self, input)
#    1502             while read_set or write_set:
#    1503                 try:
# -> 1504                     rlist, wlist, xlist = select.select(read_set, write_set, [])
#    1505                 except select.error, e:
#    1506                     if e.args[0] == errno.EINTR:
#
# KeyboardInterrupt:

# %%
print figpath
experiments = ['prior_vanilla', 'prior_vanilla_noise', 'prior_vanilla_firstorder_noise', 'prior_vanilla_firstorder']
databases = ['serre07_distractors'] * len(experiments)
labels = ['control', 'noise', 'with prior', 'noise (prior)']
mps = [mp] * len(experiments)
from SparseEdges import plot
fig, a, ax = plot(mps=mps, experiments=experiments, databases=databases, labels=labels, color=[0., 0., 1.], scale=True)    
if not(figpath==None): 
    for ext in FORMATS: fig.savefig(figpath + 'firstorder_B.' + ext)
# Out:
# INFO:SparseEdges: > computing edges for experiment prior_vanilla with database serre07_distractors
# INFO:SparseEdges:>>> For the class serre07_distractors, in experiment prior_vanilla RMSE = 0.997700
# INFO:SparseEdges: > computing edges for experiment prior_vanilla_noise with database serre07_distractors
# INFO:SparseEdges:>>> For the class serre07_distractors, in experiment prior_vanilla_noise RMSE = 0.997558
# INFO:SparseEdges: > computing edges for experiment prior_vanilla_firstorder_noise with database serre07_distractors
# INFO:SLIP:There is no imagelist, creating one: [Errno 2] No such file or directory: 'mat/prior_vanilla_firstorder_noise_serre07_distractors_images.pickle'
# INFO:SLIP: > setting up image list for serre07_distractors
# INFO:SparseEdges: >> There is no edgeslist: [Errno 2] No such file or directory: 'mat/edges/prior_vanilla_firstorder_noise_serre07_distractors_edges.npy'
# INFO:SparseEdges:>> Doing the edge extraction
# ../../CNRS/BICV-book/BICV_INT/BICV-sparse/
# Failed to plot experiment prior_vanilla_firstorder_noise with error : [Errno 2] No such file or directory: 'mat/edges/prior_vanilla_firstorder_noise_serre07_distractors/Bdn_natu133.jpg[0, 256, 0, 256].npy'
# INFO:SparseEdges: > computing edges for experiment prior_vanilla_firstorder with database serre07_distractors
# INFO:SLIP:There is no imagelist, creating one: [Errno 2] No such file or directory: 'mat/prior_vanilla_firstorder_serre07_distractors_images.pickle'
# INFO:SLIP: > setting up image list for serre07_distractors
# INFO:SparseEdges: >> There is no edgeslist: [Errno 2] No such file or directory: 'mat/edges/prior_vanilla_firstorder_serre07_distractors_edges.npy'
# INFO:SparseEdges:>> Doing the edge extraction
# Failed to plot experiment prior_vanilla_firstorder with error : [Errno 2] No such file or directory: 'mat/edges/prior_vanilla_firstorder_serre07_distractors/Bdn_natu133.jpg[0, 256, 0, 256].npy'

# %%
imageslist, edgeslist, RMSE =  mp.process('prior_vanilla_firstorder', name_database=name_database)
fig = plt.figure(figsize=(fig_width/1.618, fig_width/1.618))
ax = fig.add_subplot(111, axisbg='w', polar=True)
fig, ax = mp.histedges_theta(edgeslist, fig=fig, a=ax)
v_hist, v_theta_edges = mp.histedges_theta(edgeslist, display=False)
ax.plot((v_theta_edges[1:]+v_theta_edges[:-1])/2, np.ones_like(v_hist)*v_hist.mean(), 'r--')
ax.plot((v_theta_edges[1:]+v_theta_edges[:-1])/2+np.pi, np.ones_like(v_hist)*v_hist.mean(), 'r--')
if not(figpath==None): 
    for ext in FORMATS: fig.savefig(figpath + 'firstorder_A_bis.' + ext)
# Out:
# INFO:SparseEdges: > computing edges for experiment prior_vanilla_firstorder with database laboratory
# INFO:SLIP:There is no imagelist, creating one: [Errno 2] No such file or directory: 'mat/prior_vanilla_firstorder_laboratory_images.pickle'
# INFO:SLIP: > setting up image list for laboratory
# INFO:SparseEdges: >> There is no edgeslist: [Errno 2] No such file or directory: 'mat/edges/prior_vanilla_firstorder_laboratory_edges.npy'
# INFO:SparseEdges:>> Doing the edge extraction

# %% [markdown]
# ## Prior on second-order distribution of edge co-occurences

# %% [raw]
# pe = ParameterSet('default_param.py')
# im = Image(pe)
# lg = LogGabor(im)
# mp = SparseEdges(lg)
#
# def plot_dipole(w= pe.N_X*.3, B_phi=.1, B_theta=.8, scale=1.):
#     #D = mp.dipole(edges)
#     D = np.ones((mp.N_X, mp.N_Y, mp.n_theta, mp.n_levels))
#     x, y, theta, sf_0, C, phase = mp.N_X/2, mp.N_Y/2, mp.theta[8], mp.sf_0[2], 1, 0.
#
#
#     neighborhood = np.exp(-((mp.im.X-x)**2+(mp.im.Y-y)**2)/2/((w**2)))
#     for i_sf_0, sf_0_ in enumerate(mp.sf_0):
#         for i_theta, theta_ in enumerate(mp.theta):
#             D_theta = theta - theta_ # angle between edge's orientation and the layer's one
#             phi = np.arctan2(mp.im.Y-y, mp.im.X-x) - np.pi/2 - theta_ - D_theta/2
#             #phi = ((phi + np.pi/2  - np.pi/mp.pe.N_phi/2 ) % (np.pi)) - np.pi/2  + np.pi/mp.pe.N_phi/2
#             #theta = ((theta + np.pi/2 - np.pi/mp.pe.n_theta/2)  % (np.pi) ) - np.pi/2  + np.pi/mp.pe.n_theta/2
#             D[:, :, i_theta, i_sf_0] = np.exp(np.cos(2*phi)/B_phi**2) * np.exp(np.cos(2*D_theta)/B_theta**2)
#             if mp.pe.MP_do_mask: D[:, :, i_theta, i_sf_0] *= mp.MP_mask
#         D[:, :, :, i_sf_0] *= neighborhood[..., np.newaxis]*np.exp(-np.abs( np.log2(mp.sf_0[i_sf_0] / sf_0)) / 2)
#
#
#     phi = (np.sqrt(5) +1.)/2. # golden number
#     opts= {'vmin':0., 'vmax':1., 'interpolation':'nearest', 'origin':'upper'}
#     fig_width = 16
#     fig = plt.figure(figsize=(fig_width, fig_width/phi))
#     xmin, ymin, size = 0, 0, 1.
#     for i_sf_0, sf_0_ in enumerate(mp.sf_0):
#         a = fig.add_axes((xmin/phi, ymin, size/phi, size), axisbg='w')
#         a.axis(c='b', lw=0)
#         plt.setp(a, xticks=[])
#         plt.setp(a, yticks=[])
#         im_RGB = np.zeros((pe.N_X, pe.N_Y, 3))
#         for i_theta, theta_ in enumerate(mp.theta):
#             im_abs = np.absolute(D[:, :, i_theta, i_sf_0])
#             RGB = np.array([.5*np.sin(2*theta_ + 2*i*np.pi/3)+.5 for i in range(3)])
#             im_RGB += im_abs[:,:, np.newaxis] * RGB[np.newaxis, np.newaxis, :]
#
#         im_RGB /= im_RGB.max()
#         a.imshow(im_RGB, **opts)
#         a.grid(False)
#         i_orientation = np.mod(i_sf_0, 4)
#         if i_orientation==0:
#             xmin += size
#             ymin += size/phi**2
#         elif i_orientation==1:
#             xmin += size/phi**2
#             ymin += -size/phi
#         elif i_orientation==2:
#             xmin += -size/phi
#         elif i_orientation==3:
#             ymin += size
#         size /= phi
#
# plot_dipole()

# %%
pe = ParameterSet('default_param.py')
im = Image(pe)
lg = LogGabor(im)
mp = SparseEdges(lg)

# %%
def plot_dipole(w= pe.N_X*.3, B_phi=.1, B_theta=.8, scale=1.):
    D = mp.dipole(np.array([mp.N_X/2, mp.N_Y/2, mp.theta[8], mp.sf_0[2], 1, 0.]), w= pe.N_X*.3, B_phi=.1, B_theta=.8, scale=1.)
    
    im_RGB, im_max = [], 0
    for i_sf_0, sf_0_ in enumerate(mp.sf_0):
        im_RGB_ = np.zeros((pe.N_X, pe.N_Y, 3))
        for i_theta, theta_ in enumerate(mp.theta):
            im_abs = np.absolute(D[:, :, i_theta, i_sf_0])
            RGB = np.array([.5*np.sin(2*theta_ + 2*i*np.pi/3)+.5 for i in range(3)])
            im_RGB_ += im_abs[:,:, np.newaxis] * RGB[np.newaxis, np.newaxis, :]

        im_max = np.max((im_max, im_RGB_.max()))
        im_RGB.append(im_RGB_)
       
    phi = (np.sqrt(5) +1.)/2. # golden number
    opts= {'vmin':0., 'vmax':1., 'interpolation':'nearest', 'origin':'upper'}
    fig_width = 16
    fig = plt.figure(figsize=(fig_width, fig_width/phi))
    xmin, ymin, size = 0, 0, 1.
    
    for i_sf_0, sf_0_ in enumerate(mp.sf_0):
        a = fig.add_axes((xmin/phi, ymin, size/phi, size), axisbg='w')
        a.axis(c='b', lw=0)
        plt.setp(a, xticks=[])
        plt.setp(a, yticks=[])
        a.imshow(im_RGB[i_sf_0]/im_max, **opts)
        a.grid(False)
        i_orientation = np.mod(i_sf_0, 4)
        if i_orientation==0:
            xmin += size
            ymin += size/phi**2
        elif i_orientation==1:
            xmin += size/phi**2
            ymin += -size/phi
        elif i_orientation==2:
            xmin += -size/phi
        elif i_orientation==3:
            ymin += size
        size /= phi 

#plot_dipole()
from IPython.html.widgets import interact
_ = interact(plot_dipole, w=(pe.N_X*.01,pe.N_X,pe.N_X*.01), B_phi=(0.01, 2., 0.04), B_theta=(0.01, 2., 0.04), scale=(0.01, 2., 0.04))

# %% [markdown]
# co-circular axis of same angle are aligned.

# %%
pe = ParameterSet('default_param.py')
im = Image(pe)
lg = LogGabor(im)
mp = SparseEdges(lg)
# filters in Fourier space
edge_in, edge_bis, edge_ter = [pe.N_X*.46, pe.N_Y*.54, 18, 2], [pe.N_X*.54, pe.N_Y*.46, 17, 2], [pe.N_X*.25, pe.N_Y*.25, 6, 2]
FT_lg_in = lg.loggabor(edge_in[0], edge_in[1], 
                       theta= mp.theta[edge_in[2]], B_theta=mp.B_theta,
                       sf_0=mp.sf_0[edge_in[3]],  B_sf=mp.B_sf)
FT_lg_bis = lg.loggabor(edge_bis[0], edge_bis[1], 
                        theta= mp.theta[edge_bis[2]], B_theta=mp.B_theta,
                        sf_0=mp.sf_0[edge_bis[3]], B_sf=mp.B_sf)
FT_lg_ter = lg.loggabor(edge_ter[0], edge_ter[1], 
                        theta= mp.theta[edge_ter[2]], B_theta=mp.B_theta,
                        sf_0=mp.sf_0[edge_ter[3]], B_sf=mp.B_sf)
# mixing both and shows one
FT_lg_ = 42. *  FT_lg_in + 35.*np.exp(1j*np.pi/4.) * FT_lg_bis + 42. *  FT_lg_ter
fig = im.show_FT(FT_lg_)

# %%
image = im.invert(FT_lg_)
mp.do_whitening = False
mp.N = 5
print ' without second-order '
edges, C_res = mp.run_mp(image, verbose=True)
print ' with second-order '
mp.pe.eta_SO = .5
edges, C_res = mp.run_mp(image, verbose=True)
# Out:
#  without second-order
# Max activity  :
#  42.0  phase=  -9.34307124489e-14  deg,  @  (64, 64, 6, 2)
# Max activity  :
#  41.9706353595  phase=  10.4896831796  deg,  @  (117, 139, 18, 2)
# Max activity  :
#  34.2859346949  phase=  42.4917690996  deg,  @  (138, 118, 17, 2)
# Max activity  :
#  9.09871668235  phase=  -22.8107850213  deg,  @  (119, 137, 17, 2)
# Max activity  :
#  7.77587499422  phase=  -42.373781723  deg,  @  (61, 62, 6, 2)
#  with second-order
# Max activity  :
#  42.0  phase=  -9.34307124489e-14  deg,  @  (64, 64, 6, 2)
# Max activity  :
#  41.9706353595  phase=  10.4896831796  deg,  @  (117, 139, 18, 2)
# Max activity  :
#  25.2903057921  phase=  4.74771112174  deg,  @  (142, 113, 18, 2)
# Max activity  :
#  13.9528225545  phase=  63.1390066962  deg,  @  (136, 121, 18, 2)
# Max activity  :
#  7.39350200359  phase=  -48.550238155  deg,  @  (60, 61, 6, 2)

# %%
import matplotlib
#matplotlib.rcParams.update({'font.size': 18, 'font.family': 'STIXGeneral', 'mathtext.fontset': 'stix'})
matplotlib.rcParams.update({'text.usetex': False})
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
import matplotlib.pyplot as plt

import numpy as np
np.set_printoptions(precision=4)#, suppress=True)
# http://ipython.org/ipython-doc/stable/config/extensions/autoreload.html
#%load_ext autoreload
#%autoreload 2

# where should we store the figures generated by this notebook
figpath = None
figpath = '../../CNRS/BICV-book/BICV_INT/BICV-sparse/'
FORMATS = ['pdf', 'eps']
from NeuroTools.parameters import ParameterSet
from SLIP import Image
from LogGabor import LogGabor
from SparseEdges import SparseEdges

# %%
pe = ParameterSet('default_param.py')
im = Image(pe)
lg = LogGabor(im)
mp = SparseEdges(lg)
edgeslist = np.load('mat/edges/prior_vanilla_serre07_distractors_edges.npy')
v_hist = mp.cohistedges(edgeslist, display=False)
v_hist.mean(), v_hist.shape
# Out:
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.002704
# theta 0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.002145
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.002918
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000360
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000734
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.003335
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.001726
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.005630
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.003594
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.010569
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000725
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.007069
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.002509
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.004020
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.005901
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.002616
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.003119
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000621
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.016766
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.002359
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.002806
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.001437
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000540
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.003845
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.006646
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.003724
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.001267
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.004615
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.004490
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.011514
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.002388
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.002508
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.001285
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000537
#  0.0654498469498  /  -0.0654498469498
# theta 0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.002347
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.002822
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.001498
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.001962
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.000580
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.004790
#  0.0654498469498  /  -0.0654498469498
# theta 0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.001797
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.002144
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.001322
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.003579
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.002603
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.091359
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.001692
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.001934
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.005688
#  0.0654498469498  /  -0.0654498469498
# theta
# ERROR:SparseEdges: less than 80 percent of co-occurences within ranges: 0.004128
#  0.0654498469498  /  -0.0654498469498
# (0.00011574074074074075, (6, 12, 24, 5))

# %%
def plot_dipole(w= pe.N_X*.3, B_phi=.1, B_theta=.8, scale=1.):
    D = np.ones((mp.N_X, mp.N_Y, mp.n_theta, mp.n_levels))
    x, y, theta, sf_0, C, phase = mp.N_X/2, mp.N_Y/2, mp.theta[8], mp.sf_0[2], 1, 0.
    d = np.sqrt((mp.im.X-x)**2+(mp.im.Y-y)**2)
    #if mp.pe.scale_invariant: d *= np.sqrt(Sf_0[:, np.newaxis]*Sf_0[np.newaxis, :])#*np.sqrt(self.N_X)
    d *= mp.pe.d_width # distance in visual angle
    i_d = np.floor((d - mp.pe.d_min)/(mp.pe.d_max-mp.pe.d_min)*mp.pe.N_r)
    print i_d

    for i_sf_0, sf_0_ in enumerate(mp.sf_0):
        loglevel = np.log2(sf_0_-sf_0)
        i_loglevel = np.floor((d + mp.pe.loglevel_max)/(2*mp.pe.loglevel_max)*mp.pe.N_r)
        for i_theta, theta_ in enumerate(mp.theta):
            D_theta = theta - theta_ # angle between edge's orientation and the layer's one
            phi = np.arctan2(mp.im.Y-y, mp.im.X-x) - np.pi/2 - theta_ - D_theta/2
            # putting everything in the [-pi/2, pi/2[ quadrant
            theta = ((D_theta + np.pi/2 - np.pi/mp.pe.n_theta/2)  % (np.pi) ) - np.pi/2  + np.pi/mp.pe.n_theta/2
            phi = ((phi + np.pi/2  - np.pi/mp.pe.N_phi/2 ) % (np.pi)) - np.pi/2  + np.pi/mp.pe.N_phi/2
            # discretizing
            i_theta = np.floor((theta + np.pi/2)/np.pi*mp.pe.n_theta) * np.ones_like(i_d)
            i_phi = np.floor((phi + np.pi/2)/np.pi*mp.pe.N_phi)
            print i_d.max(), i_phi.max(), i_theta.max(), i_loglevel.max()
            D[:, :, i_theta, i_sf_0] = v_hist[i_d.astype(int), i_phi.astype(int), i_theta.astype(int), i_loglevel.astype(int)]

    
    im_RGB, im_max = [], 0
    for i_sf_0, sf_0_ in enumerate(mp.sf_0):
        im_RGB_ = np.zeros((pe.N_X, pe.N_Y, 3))
        for i_theta, theta_ in enumerate(mp.theta):
            im_abs = np.absolute(D[:, :, i_theta, i_sf_0])
            RGB = np.array([.5*np.sin(2*theta_ + 2*i*np.pi/3)+.5 for i in range(3)])
            im_RGB_ += im_abs[:,:, np.newaxis] * RGB[np.newaxis, np.newaxis, :]

        im_max = np.max((im_max, im_RGB_.max()))
        im_RGB.append(im_RGB_)
       
    phi = (np.sqrt(5) +1.)/2. # golden number
    opts= {'vmin':0., 'vmax':1., 'interpolation':'nearest', 'origin':'upper'}
    fig_width = 16
    fig = plt.figure(figsize=(fig_width, fig_width/phi))
    xmin, ymin, size = 0, 0, 1.
    
    for i_sf_0, sf_0_ in enumerate(mp.sf_0):
        a = fig.add_axes((xmin/phi, ymin, size/phi, size), axisbg='w')
        a.axis(c='b', lw=0)
        plt.setp(a, xticks=[])
        plt.setp(a, yticks=[])
        a.imshow(im_RGB[i_sf_0]/im_max, **opts)
        a.grid(False)
        i_orientation = np.mod(i_sf_0, 4)
        if i_orientation==0:
            xmin += size
            ymin += size/phi**2
        elif i_orientation==1:
            xmin += size/phi**2
            ymin += -size/phi
        elif i_orientation==2:
            xmin += -size/phi
        elif i_orientation==3:
            ymin += size
        size /= phi 

#plot_dipole()
from IPython.html.widgets import interact
_ = interact(plot_dipole, w=(pe.N_X*.01,pe.N_X,pe.N_X*.01), B_phi=(0.01, 2., 0.04), B_theta=(0.01, 2., 0.04), scale=(0.01, 2., 0.04))
# Out:
# [[ 27927.  27818.  27710. ...,  27602.  27710.  27818.]
#  [ 27818.  27709.  27600. ...,  27492.  27600.  27709.]
#  [ 27710.  27600.  27491. ...,  27382.  27491.  27600.]
#  ...,
#  [ 27602.  27492.  27382. ...,  27273.  27382.  27492.]
#  [ 27710.  27600.  27491. ...,  27382.  27491.  27600.]
#  [ 27818.  27709.  27600. ...,  27492.  27600.  27709.]]
# 27927.0 12.0 20.0 3494.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-34f675980036> in plot_dipole(w, B_phi, B_theta, scale)
#      21             i_phi = np.floor((phi + np.pi/2)/np.pi*mp.pe.N_phi)
#      22             print i_d.max(), i_phi.max(), i_theta.max(), i_loglevel.max()
# ---> 23             D[:, :, i_theta, i_sf_0] = v_hist[i_d.astype(int), i_phi.astype(int), i_theta.astype(int), i_loglevel.astype(int)]
#      24
#      25
#
# IndexError: index 27927 is out of bounds for axis 0 with size 6

# %%
# %%writefile experiment_fig-secondorder.py
import __init__
import numpy as np
from NeuroTools.parameters import ParameterSet
from SLIP import Image
from LogGabor import LogGabor
from SparseEdges import SparseEdges

pe = ParameterSet('default_param.py')
im = Image(pe)
lg = LogGabor(im)
mp = SparseEdges(lg)

for name_database in ['serre07_distractors', 'laboratory']:
    # control experiment
    imageslist, edgeslist, RMSE = mp.process(exp='prior_vanilla', name_database=name_database)
    imageslist, edgeslist_noise, RMSE = mp.process(exp='prior_vanilla_noise', name_database=name_database, noise=pe.noise)

    try:
        mp.pe.eta_SO = .5
        imageslist, edgeslist, RMSE =  mp.process(exp='prior_vanilla_secondorder', name_database=name_database)
        imageslist, edgeslist, RMSE = mp.process(exp='prior_vanilla_secondorder_noise', name_database=name_database, noise=pe.noise)
    except:
        print('run again once first batches are finished ')

# %%
# %run experiment_fig-secondorder.py

# %%
print figpath
experiments = ['prior_vanilla', 'prior_vanilla_secondorder']
databases = ['serre07_distractors'] * len(experiments)
mps = [mp, mp]
from SparseEdges import plot
labels = ['control', '2nd-order prior']
fig, a, ax = plot(mps=mps, experiments=experiments, databases=databases, labels=labels, color=[1., 0., 1.])    
if not(figpath==None): 
    for ext in FORMATS: fig.savefig(figpath + 'sparseedges_B.' + ext)

# %% [markdown]
# ## Application to segmentation

# %%
# %%writefile experiment_example4.py
import __init__
import numpy as np
from NeuroTools.parameters import ParameterSet
from SLIP import Image
from LogGabor import LogGabor
from SparseEdges import SparseEdges
pe = ParameterSet('default_param.py')
pe.N = 210
#pe.B_sf = 1.5
#pe.do_whitening = False
#pe.base_levels = 4
pe.n_theta = 48

# defining input image as Lena
from pylab import imread
image = imread('database/Geisler01Fig7A.png').mean(axis=-1)
print image.mean(), image.std()

im = Image(pe)
image = im.normalize(image, center=True)
print image.mean(), image.std()

lg = LogGabor(im)
mp = SparseEdges(lg)
print mp.n_levels, mp.sf_0

matname = 'mat/example4.npy'
try:
    edges = np.load(matname)
except:
    edges, C_res = mp.run_mp(image, verbose=True)
    np.save(matname, edges)

# %%
#!rm mat/example4.npy
#print pe
# %run experiment_example4.py

# %%
edges = np.load('mat/example4.npy')
#edges[0, :] = pe.N_X - edges[0,:] # HACK
#edges[2, :] = - edges[2,:] # HACK
#edges[:, 119] = edges[:, 118] # HACK
fig_width_pt = 318.670  # Get this from LaTeX using \showthe\columnwidth
inches_per_pt = 1.0/72.27               # Convert pt to inches
fig_width = fig_width_pt*inches_per_pt  # width in inches
pe.figsize_edges = 12
pe.figsize_edges = .382 * fig_width
pe.scale = 1.
pe.line_width = 1.5

from pylab import imread
image = imread('database/Geisler01Fig7A.png').mean(axis=-1)
image = im.normalize(image, center=True)

v_max = 1.*image.max()
v_min = -v_max
fig, a = mp.show_edges(edges, image=image, v_min=v_min, v_max=v_max, color='toto', show_phase=False) #pedestal=.0, gamma=.3,

# %%
v_hist = np.load('mat/prior_vanilla_serre07_distractors_hist.npy')
print v_hist.max(), v_hist.shape, 1./np.prod(v_hist.shape), np.prod(v_hist.shape)*v_hist.mean(axis=(1,2,3)), np.prod(v_hist.shape)*v_hist.std(axis=(1,2,3))

# %%
# explicit
def P_ij(edges, v_hist):
    P = np.zeros((edges.shape[1], edges.shape[1]))
    for i in range(edges.shape[1]):
        for j in range(i+1, edges.shape[1]):
            edge_A = edges[:, i]
            edge_B = edges[:, j]
            dx = edge_B[0] - edge_A[0]
            dy = edge_B[1] - edge_A[1]
            d = np.sqrt(dx**2 + dy**2)
            theta = edge_B[2] - edge_A[2]
            phi = np.arctan2(dy, dx) - np.pi/2 - edge_A[2] - theta/2
            # np.exp(-d**2/5.) * 
            P[i, j] = np.exp( np.cos(theta) / ( 500*np.pi/180.)**2) \
                    * np.exp(np.cos(phi) / (5*np.pi/180.)**2)
            P[j, i] = P[i, j]
    for i in range(edges.shape[1]):
        P[i, :] /= P[i, :].sum()
    return P
P = P_ij(edges, v_hist)

# %%
# computed from natural images
def P_ij(edges, v_hist):
    P = np.zeros((edges.shape[1], edges.shape[1]))
    for i in range(edges.shape[1]):
        for j in range(i+1, edges.shape[1]):
            try:
                v_hist_ = mp.cohistedges(edges[:, [i, j]][:, :, np.newaxis], display=False)
                p = (v_hist_ * v_hist).sum()
                if np.isnan(p): p = 0.
            except:
                p = 0.
            P[i, j] = p
            P[j, i] = P[i, j]
    for i in range(edges.shape[1]):
 
        P[i, :] /= P[i, :].sum()
    return P
P = P_ij(edges, v_hist)

# %%
plt.imshow(P)
print P.max(), P.sum(axis=1)

# %%
p = np.ones((edges.shape[1],)) #* edges[4, :]
for step in range(15):
    p /= p.sum()
    p = np.dot( p.T, P)
edges[4, :] = p
fig, a = mp.show_edges(edges, image=image, v_min=v_min, v_max=v_max, color='toto', show_phase=False) #

# %%
if not(figpath==None): 
    for ext in FORMATS: fig.savefig(figpath + 'Geisler01Fig7.' + ext)

# %% [markdown]
# ### application to a natural image

# %%
# %run experiment_example2.py
#edges = np.load('mat/example2.npy')
v_hist_d = np.load('mat/prior_vanilla_serre07_distractors_hist.npy')
P_d = P_ij(edges, v_hist_d)
v_hist_t = np.load('mat/prior_vanilla_serre07_targets_hist.npy')
P_t = P_ij(edges, v_hist_t)

# %%
p_t = np.ones((edges.shape[1],)) * edges[4, :]
p_t /= p_t.sum()
for step in range(40):
    p_t = np.dot( p_t.T, P_t)
    p_t /= p_t.sum()
    
p_d = np.ones((edges.shape[1],)) * edges[4, :]
p_d /= p_d.sum()
for step in range(40):
    p_d = np.dot( p_d.T, P_d)
    p_d /= p_d.sum()

# %%
print v_hist_d==v_hist_t#print p_t, p_d, p_d.max()
edges[4, :] = p_d - p_t #(p_d - p_t) # np.log(p_t/p_d)
print np.std(edges[4, :]), np.absolute(edges[4, :]).max()
edges[4, :] /= np.absolute(edges[4, :]).max()
print edges[4, :], p_d.max()
image = im.normalize(image, center=True)
fig_width_pt = 318.670  # Get this from LaTeX using \showthe\columnwidth
inches_per_pt = 1.0/72.27               # Convert pt to inches
fig_width = fig_width_pt*inches_per_pt  # width in inches
pe.figsize_edges = .382 * fig_width
fig, a = mp.show_edges(edges, image=image, color='toto', show_phase=False) #, pedestal=.0, gamma=.3
#fig, a = mp.show_edges(edges, image=image, v_min=v_min, v_max=v_max, color='toto', show_phase=False) #

# %%
if not(figpath==None): 
    for ext in FORMATS: fig.savefig(figpath + 'segmentation.' + ext)

# %% [markdown]
# ## some book keeping for the notebook

# %%
# %install_ext https://raw.githubusercontent.com/rasbt/python_reference/master/ipython_magic/watermark.py
# %load_ext watermark
# %watermark

# %%
# %install_ext http://raw.github.com/jrjohansson/version_information/master/version_information.py
# %load_ext version_information
# %version_information numpy, scipy, matplotlib, sympy

# %%
# CSS styling within IPython notebook
from IPython.core.display import HTML
def css_styling():
    styles = open("custom.css", "r").read()
    return HTML(styles)
css_styling()
