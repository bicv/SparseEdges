# %% [markdown]
# ## SparseEdges

# %% [markdown]
# ## A bio-inspired sparse representation of edges in natural images

# %% [markdown]
# Table of content
#
# * [What is the SparseEdges package?](#What-is-the-SparseEdges-package?)
# * [Installing](#Installing)
# * [testing one step](#testing-one-step)

# %%
#%load README.md

# %% [markdown]
# What is the SparseEdges package?
# ================================
#
# This page describes the SparseEdges package which provides with tools to extarct a sparse representation of edges in images.
#
# This algorithm was presented in the following paper:
#
# ~~~~{.bibtex}
# @article{Fischer07,
#     author = {Perrinet, Laurent U.},
#     title = {Sparse models for Computer Vision},
#     abstract = {The representation of images in the brain is known to be sparse.
# That is, as neural activity is recorded in a visual area
# ---for instance the primary visual cortex of primates---
# only a few neurons are active at a given time with respect to the whole population.
# It is believed that such a property reflects the efficient match of the representation
# with the statistics of natural scenes.
# Applying such a paradigm to computer vision
# therefore seems a promising approach towards more biomimetic algorithms.
# Herein, we will describe a biologically-inspired approach to this problem.
# First, we will describe an unsupervised learning paradigm
# which is particularly adapted to the efficient coding of image patches.
# Then, we will outline a complete multi-scale framework ---SparseLets---
# implementing a biologically inspired sparse representation of natural images.
# Finally, we will propose novel methods for integrating
# prior information into these algorithms and provide some preliminary experimental results.
# We will conclude by giving some perspective on applying such algorithms to computer vision.
# More specifically, we will propose that bio-inspired approaches
# may be applied to computer vision using predictive coding schemes,
# sparse models being one simple and efficient instance of such schemes.},
#     year = {2014}
# }
# ~~~~
#
# This package gives a python implementation.
#
# Moreover, it gives additional tools to compute useful stistics in images; first- and second order statistics of co-occurences in images.
#
# More information is available @ http://pythonhosted.org/SparseEdges

# %% [markdown]
# ## Installing

# %%
#!pip install -U -r requirements.txt

# %% [markdown]
# [Back to top](#SparseEdges)

# %%
import matplotlib
#matplotlib.rcParams.update({'font.size': 18, 'font.family': 'STIXGeneral', 'mathtext.fontset': 'stix'})
matplotlib.rcParams.update({'text.usetex': False})
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
#%config InlineBackend.figure_format = 'svg' #raw_input('what figure format should we use? ') or default
#%config InlineBackend.rc = {'font.size': 14, 'text.usetex': False, 'savefig.dpi': 96, 'figure.figsize':  (13.0, 8.0), 'figure.subplot.bottom': 0.125}
import matplotlib.pyplot as plt

import numpy as np
np.set_printoptions(precision=4)#, suppress=True)
# http://ipython.org/ipython-doc/stable/config/extensions/autoreload.html
#%load_ext autoreload
#%autoreload 2

# where should we store the figures generated by this notebook
figpath = ''
figpath = '../../CNRS/BICV-book/BICV_sparse/src/'

# %%
from NeuroTools.parameters import ParameterSet
from SLIP import Image
from LogGabor import LogGabor
from SparseEdges import SparseEdges

# %%
#! this test report is about the MatchingPursuit class:
print SparseEdges.__doc__
# Out:
# None

# %%
#! defining framework
#!-------------------
pe = ParameterSet('default_param.py')
pe.N = 4
pe.do_mask=False
pe.MP_alpha=1.
pe.do_whitening = False
im = Image(pe)
lg = LogGabor(im)
mp = SparseEdges(lg)

print 'Range of spatial frequencies: ', mp.sf_0
# Out:
# Range of spatial frequencies:  [ 0.618   0.382   0.2361  0.1459  0.0902  0.0557  0.0344  0.0213  0.0132
#   0.0081  0.005 ]

# %%
print 'Range of angles: ', mp.theta*180./np.pi
# Out:
# Range of angles:  [-82.5 -75.  -67.5 -60.  -52.5 -45.  -37.5 -30.  -22.5 -15.   -7.5   0.
#    7.5  15.   22.5  30.   37.5  45.   52.5  60.   67.5  75.   82.5  90. ]

# %% [markdown]
# ## Matching Pursuit

# %% [markdown]
# ### testing one step

# %% [markdown]
# let's synthetise one image using 2 filters and check that they are correctly retrieved using the different steps from Matching Pursuit

# %%
edge_in, edge_bis = [2*pe.N_X/3, pe.N_Y/2, 2, 2], [pe.N_X/3, pe.N_Y/3, 8, 4]

# %%
# filters in Fourier space
FT_lg_in = lg.loggabor(edge_in[0], edge_in[1], sf_0=mp.sf_0[edge_in[3]],
                         B_sf=mp.B_sf, theta= mp.theta[edge_in[2]], B_theta=mp.B_theta)
FT_lg_bis = lg.loggabor(edge_bis[0], edge_bis[1], sf_0=mp.sf_0[edge_bis[3]],
                         B_sf=mp.B_sf, theta= mp.theta[edge_bis[2]], B_theta=mp.B_theta)
# mixing both and shows one
FT_lg_ = 42. *  FT_lg_in - 4.*np.sqrt(2)*np.exp(1j*np.pi/4.) * FT_lg_bis
fig = im.show_FT(FT_lg_)

# %%
# computing activity
image = im.invert(FT_lg_)
C = mp.init(image)

# %%
# getting best match
edge_star = mp.argmax(C)
print np.sum(image**2), edge_star,  edge_in,  C[edge_star]
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.imshow(im.normalize(image))
plt.plot([edge_star[1]], [edge_star[0]], 'r*')
v = plt.axis((0, pe.N_X, pe.N_Y, 0))
plt.subplot(122)
plt.imshow(im.normalize(np.absolute(C[:,:,edge_star[2],edge_star[3]])))
plt.plot([edge_star[1]], [edge_star[0]], 'r*')
v = plt.axis((0, pe.N_X, pe.N_Y, 0))
# Out:
# 1796.00376266 (170, 128, 2, 2) [170, 128, 2, 2] (42.0000895867+6.56468227047e-10j)

# %%
#! showing the winner
#pylab.imshow(im.normalize(lg_star), **opts)
FT_star = lg.loggabor(edge_star[0], edge_star[1], sf_0=mp.sf_0[edge_star[3]],
                         B_sf=mp.B_sf, theta= mp.theta[edge_star[2]], B_theta=mp.B_theta)
im_star = im.invert(FT_star)
fig = im.show_FT(FT_star, axis=True)

# %%
#! normalization should give 1 for resp. sum image energy, half mean spectrum energy, max coco:
print np.sum(im_star**2), np.mean(np.abs(FT_star)**2)/2, im.FTfilter(im_star, FT_star).max()
# Out:
# 1.00000213301 1.0 1.00000213301

# %%
edge_star_in = np.array([edge_star[0], edge_star[1], mp.theta[edge_in[2]], edge_star[3], np.absolute(C[edge_star]), np.angle(C[edge_star])])
#edge_star_in = np.array([edge_star[0], edge_star[1], np.pi/2, edge_star[3], C[edge_star]])
mp.pe.figsize_edges = 9
#mp.pe.scale = 20.
fig, a = mp.show_edges(edge_star_in[:, np.newaxis], image=image)

# %%
#! we substract the residual from the image
image_res = (image - C[edge_star] * im_star).real # C_star*lg_star
print C[edge_star], image[edge_star[0], edge_star[1]], im_star[edge_star[0], edge_star[1]]*C[edge_star].real, image_res[edge_star[0], edge_star[1]],
# Out:
# (42.0000895867+6.56468227047e-10j) 13.6431128415 13.6431438899 -3.104842882e-05

# %%
C_res = mp.init(image_res)
edge_bis = mp.argmax(C_res)
print np.sum(image_res**2), edge_star, edge_bis, C_res[edge_star], C_res[edge_bis]
# Out:
# 32.000000008 (170, 128, 2, 2) (85, 85, 8, 4) (-8.95864812836e-05+6.56525690058e-10j) (-4-4j)

# %%
#! plotting the residual image and activity :
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.imshow(im.normalize(image_res))
plt.plot([edge_star[1]], [edge_star[0]], 'b*')
plt.plot([edge_bis[1]], [edge_bis[0]], 'r*')
v = plt.axis((0, pe.N_X, pe.N_Y, 0))
plt.subplot(122)
plt.imshow(im.normalize(np.absolute(C_res[:,:,edge_star[2],edge_star[3]])))
plt.plot([edge_star[1]], [edge_star[0]], 'b*')
plt.plot([edge_bis[1]], [edge_bis[0]], 'r*')
v = plt.axis((0, pe.N_X, pe.N_Y, 0))

# %%
#! or directly the activity
C_res = mp.backprop(C, edge_star)
edge_bis = mp.argmax(C_res)
print np.sum(image_res**2), edge_star, C_res[edge_star], C_res[edge_bis]
# Out:
# 32.000000008 (170, 128, 2, 2) (-8.95864812804e-05+5.89989972068e-14j) (-4-4j)

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.imshow(im.normalize(np.absolute(C[:,:,edge_star[2],edge_star[3]])))
plt.plot([edge_star[1]], [edge_star[0]], 'b*')
plt.plot([edge_bis[1]], [edge_bis[0]], 'r*')
v = plt.axis((0, pe.N_X, pe.N_Y, 0))
plt.subplot(122)
plt.imshow(im.normalize(np.absolute(C_res[:,:,edge_star[2],edge_star[3]])))
plt.plot([edge_star[1]], [edge_star[0]], 'b*')
plt.plot([edge_bis[1]], [edge_bis[0]], 'r*')
v = plt.axis((0, pe.N_X, pe.N_Y, 0))

# %%
edge_star_bis = np.array([edge_bis[0], edge_bis[1], mp.theta[edge_bis[2]], edge_bis[3], np.absolute(C[edge_bis]), np.angle(C[edge_bis])])

print np.vstack((edge_star_in, edge_star_bis))
fig, a = mp.show_edges(np.vstack((edge_star_in, edge_star_bis)).T, image=image)
# Out:
# [[  1.7000e+02   1.2800e+02  -1.1781e+00   2.0000e+00   4.2000e+01
#     1.5630e-11]
#  [  8.5000e+01   8.5000e+01  -3.9270e-01   4.0000e+00   5.6569e+00
#    -2.3562e+00]]

# %% [markdown]
# [Back to top](#SparseEdges)

# %% [markdown]
# ### testing three steps

# %%
# filters in Fourier space
FT_lg_in = lg.loggabor(edge_in[0], edge_in[1], 
                       theta= mp.theta[edge_in[2]], B_theta=mp.B_theta,
                       sf_0=mp.sf_0[edge_in[3]],  B_sf=mp.B_sf)
FT_lg_bis = lg.loggabor(edge_bis[0], edge_bis[1], 
                        theta= mp.theta[edge_bis[2]], B_theta=mp.B_theta,
                        sf_0=mp.sf_0[edge_bis[3]], B_sf=mp.B_sf)
# mixing both and shows one
FT_lg_ = 42. *  FT_lg_in + 16.*np.exp(1j*np.pi/4.) * FT_lg_bis

# %%
print mp.N, mp.pe.MP_alpha
fig = im.show_FT(FT_lg_)
# Out:
# 4 1.0

# %%
image = im.invert(FT_lg_)
edges, C_res = mp.run_mp(image, verbose=True)
# Out:
# Max activity  :  42.0000895851  phase=  -2.53327454384e-09  deg,  @  (170, 128, 2, 2)
# Max activity  :
#  16.0  phase=  45.0  deg,  @  (85, 85, 8, 4)
# Max activity  :
#  8.95853272834e-05  phase=  179.998812334  deg,  @  (170, 128, 2, 2)
# Max activity  :
#  1.91086122064e-10  phase=  0.00118763016989  deg,  @  (170, 128, 2, 2)

# %%
mp.pe.scale = 1.
fig, a = mp.show_edges(edges, image=image)

# %% [markdown]
# Note: to store the complex value of the coefficient, we use the fact that it is easy to transform a complex number to 2 reals and back:

# %%
z = np.sqrt(2)*np.exp(1j*np.pi/4.)
z_, z_p = np.absolute(z), np.angle(z)
print z, z_*np.exp(1j*z_p)
# Out:
# (1+1j) (1+1j)

# %% [markdown]
# [Back to top](#SparseEdges)

# %% [markdown]
# ### Testing edge detection on a natural image

# %%
# %%writefile test/experiment_example.py
import __init__
import numpy as np
from NeuroTools.parameters import ParameterSet
from SLIP import Image
from LogGabor import LogGabor
from SparseEdges import SparseEdges
pe = ParameterSet('default_param.py')

# defining input image as Lena
from pylab import imread
image = imread('database/yelmo' + str(pe.N_X) + '.png').mean(axis=-1)#.flipud().fliplr()
image = imread('database/lena' + str(pe.N_X) + '.png').mean(axis=-1)#.flipud().fliplr()
#print image.mean(), image.std()

pe.N = 512

im = Image(pe)
image = im.normalize(image, center=True)
#print image.mean(), image.std()
lg = LogGabor(im)
mp = SparseEdges(lg)

matname = 'mat/example.npy'
matname_RMSE = 'mat/example_RMSE.npy'
try:
    edges = np.load(matname)
    RMSE = np.load(matname_RMSE)
except:
    edges, C_res = mp.run_mp(image, verbose=True)
    print edges.shape
    np.save(matname, edges)    

    RMSE = np.ones(mp.N)
    image_ = image.copy()
    image_rec = np.zeros_like(image_)
    if mp.do_whitening: image_ = mp.im.whitening(image_)
    for i_N in range(mp.N):
        image_rec += mp.reconstruct(edges[:, i_N][:, np.newaxis])
        RMSE[i_N] =  ((image_*im.mask-image_rec*im.mask)**2).sum()

    np.save(matname_RMSE, RMSE)
# Out:
# Overwriting test/experiment_example.py

# %%
#!rm mat/example.npy mat/example_RMSE.npy
# !ls -l  mat/example.npy mat/example_RMSE.npy
# Out:
# -rw-r--r-- 1 lolo staff 24656 Jan  9 19:17 mat/example.npy
# -rw-r--r-- 1 lolo staff  4176 Jan  9 19:17 mat/example_RMSE.npy

# %%
# %run test/experiment_example.py

# %%
edges = np.load(matname)
#edges[0, :] = pe.N_X - edges[0,:] # HACK
#edges[2, :] = - edges[2,:] # HACK
#edges[:, 119] = edges[:, 118] # HACK
fig_width_pt = 318.670  # Get this from LaTeX using \showthe\columnwidth
inches_per_pt = 1.0/72.27               # Convert pt to inches
fig_width = fig_width_pt*inches_per_pt  # width in inches
mp.pe.figsize_edges = .382 * fig_width
mp.pe.line_width = 1.
mp.pe.scale = 1.
fig, a = mp.show_edges(edges, image=image, show_phase=True)#, pedestal=.0, gamma=1.) #, color='toto'

FORMATS = ['pdf', 'eps']
if not(figpath==''): 
    for ext in FORMATS: fig.savefig(figpath + '/figures/SparseLets_A_rec.' + ext)
    for ext in FORMATS: fig.savefig(figpath + '/figures/SparseLets_A.' + ext)

print RMSE.shape, edges.shape
# Out:
# (512,) (6, 512)

# %%
#! recontructing the image from the edges
image_rec = mp.reconstruct(edges)
print 'RMSE-W = ', ((im.whitening(image)-image_rec)**2).sum()/((im.whitening(image))**2).sum()
#fig, a = mp.show_edges(edges, image=image_rec*1.)
fig, a = mp.show_edges(edges, image=im.dewhitening(image_rec)*1.)
# Out:
# RMSE-W =  0.375351491534

# %%
opts= {'vmin':0., 'vmax':1., 'interpolation':'nearest', 'origin':'upper'}

#pe = ParameterSet('default_param.py')
#im = Image(pe)
#lg = LogGabor(im)
#mp = SparseEdges(lg)

phi = (np.sqrt(5) +1.)/2. # golden number
fig = plt.figure(figsize=(fig_width, fig_width/phi))
xmin, ymin, size = 0, 0, 1.

edges = np.load(matname)
im_RGB =[]
for i_level in range(mp.n_levels):
    im_RGB_ = np.zeros((np.ceil(pe.N_X*phi**-i_level), np.ceil(pe.N_Y*phi**-i_level), 3))
    im_RGB.append(im_RGB_)

for edge in edges.T:
    x, y, theta, sf, coeff, phase = edge
    level = np.argmax(mp.sf_0 == sf)
    #print sf, np.argmax(mp.sf_0 == sf), level
    i_x, i_y = int(x*phi**-level), int(y*phi**-level)
    #print i_x, i_y, im_RGB[level].shape
    #im_RGB[level][i_x, i_y, :] += coeff * np.array([.5*np.sin(2*theta + 2*i*np.pi/3)+.5 for i in range(3)])
    im_RGB[level][i_x, i_y, :] += np.array([.5*np.sin(2*theta + 2*i*np.pi/3)+.5 for i in range(3)])
    
for i_level in range(mp.n_levels):
    a = fig.add_axes((xmin/phi, ymin, size/phi, size), axisbg='w')
    a.axis(c='b', lw=0)
    plt.setp(a, xticks=[])
    plt.setp(a, yticks=[])

    im_RGB[i_level] /= im_RGB[i_level].max()
    a.imshow(im_RGB[i_level], **opts)
    a.grid(False)
    i_orientation = np.mod(i_level, 4)
    if i_orientation==0:
        xmin += size
        ymin += size/phi**2
    elif i_orientation==1:
        xmin += size/phi**2
        ymin += -size/phi
    elif i_orientation==2:
        xmin += -size/phi
    elif i_orientation==3:
        ymin += size
    size /= phi 
    #print i_orientation, xmin, ymin, size
if not(figpath==''): 
    for ext in FORMATS: fig.savefig(figpath + '/figures/SparseLets_A_pyr.' + ext)
# Out:
# -c:33: RuntimeWarning: invalid value encountered in divide

# %%
# checking the quick computation of the RMSE in MP
image_W = im.whitening(image)
RMSE_0 = (image_W**2).sum() * mp.MP_mask.mean()
print image_W.mean(), image_W.std(), np.sqrt(RMSE_0), np.sqrt(RMSE[0])
    

RMSE_MP = np.ones(pe.N)
RMSE_MP[1:] = 1. - np.cumsum(edges[4, :-1]**2) * (2 -  mp.pe.MP_alpha)/mp.pe.MP_alpha / RMSE_0

plt.figure(figsize=(12,6))
plt.subplot(111)
plt.plot(RMSE/RMSE[0], 'ro', label='true')
plt.plot(RMSE_MP, 'g--', label='MP-vec')
plt.legend()
# Out:
# 2.57736540443e-15 0.159211134368 34.1380750434 18.5370933556

# %%
#    RMSE = np.ones(pe.N)
#    for i_N in range(1, pe.N):
#        image_ = mp.reconstruct(edges[:, :i_N])
#        RMSE[i_N] =  ((image_W-image_)**2).sum() / RMSE_0
RMSE= np.load('mat/example.npy')
print RMSE.shape, mp.N
# Out:
# (6, 512) 512

# %% [markdown]
# [Back to top](#SparseEdges)

# %% [markdown]
# ### Showing progressive reconstruction

# %%
import os 
pe = ParameterSet('default_param.py')
im = Image(pe)
lg = LogGabor(im)
mp = SparseEdges(lg)

list_of_number_of_edge = [ 0, 1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048] # np.logspace(1, 10, 10, base=2) #

# defining input image as Lena
from pylab import imread
image = imread('database/yelmo' + str(pe.N_X) + '.png').mean(axis=-1)#.flipud().fliplr()
image = imread('database/lena' + str(pe.N_X) + '.png').mean(axis=-1)#.flipud().fliplr()

vmax = image.max()

matname = 'mat/example.npy'
try:
    edges = np.load(matname)
except:
    edges, C_res = mp.run_mp(image, verbose=True)
    np.save(matname, edges)      

fig_movie, axs = plt.subplots(1, len(list_of_number_of_edge), figsize=(3, 3*len(list_of_number_of_edge))) # fib

for i_ax, number_of_edge in enumerate(list_of_number_of_edge):
    image_ = mp.reconstruct(edges[:, :number_of_edge][..., np.newaxis])
#            image_ = im.dewhitening(image_)

    fig_movie, axs[i_ax] = mp.show_edges(edges[:, :number_of_edge], image=image_/vmax, fig=fig_movie, a=axs[i_ax], norm=False)
    
    figname = os.path.join(pe.figpath, 'MP_' + str(number_of_edge) + '.png')
    if not(os.path.isfile(figname)):
        try:
            fig, a = mp.show_edges(edges[:, :number_of_edge], image=(image-image_)/vmax, norm=False)
            fig.savefig(figname)
            plt.close('all')
        except Exception, e:
            print 'Failed to make image ', figname, ', error : ', e

    figname = os.path.join(pe.figpath,  'MP_' + str(number_of_edge) + '_reconstruct.png')
    if not(os.path.isfile(figname)):
        try:
            fig, a = mp.show_edges(edges[:, :number_of_edge], image=image_/vmax, norm=False)
            fig.savefig(figname)
            plt.close('all')
        except Exception, e:
            print 'Failed to make reconstruct image ', figname, ', error : ', e

fig.show()

# %% [markdown]
# ### Effect of parameters on edge extraction: image size

# %%
# %%writefile test/experiment_fig-sparselets.py
"""

$ python test/experiment_fig-sparselets.py ../../CNRS/BICV-book/BICV_sparse/src/

$ rm -fr **/SparseLets* **/**/SparseLets* 

"""

from NeuroTools.parameters import ParameterSet
from SLIP import Image
from LogGabor import LogGabor
from SparseEdges import SparseEdges, plot
import sys

pe = ParameterSet('default_param.py')

def init_pe(pe, N_X=pe.N_X, N_image=pe.N_image, N=pe.N, path=''):
    pe.N_image = N_image
    pe.N_X = N_X
    pe.N_Y = N_X
    pe.N = N
    pe.seed = 42
    pe.figpath = path + 'figures/'
    pe.edgefigpath = path + 'figures/edges/'
    pe.matpath = path + 'mat/'
    pe.edgematpath = path + 'mat/edges/'
    im = Image(pe)
    lg = LogGabor(im)
    mp = SparseEdges(lg)
    return mp

dofig = True
try:
    path = sys.argv[1]
except:
    path = '.'
    dofig = False
    
mps = []
for size, size_str in zip([16, 32, 64, 128, 256], ['_016', '_032', '_064',  '_128', '']):
    mp = init_pe(pe, N_X=size, N_image=pe.N_image*pe.N_X/size, N=pe.N*size**2/pe.N_X**2, path=path)
    mp.process('SparseLets' + size_str)
    mps.append(mp)

import matplotlib.pyplot as plt
fig_width_pt = 318.670 # Get this from LaTeX using \showthe\columnwidth
inches_per_pt = 1.0/72.27               # Convert pt to inches
fig_width = fig_width_pt*inches_per_pt  # width in inches
fig = plt.figure(figsize=(fig_width, fig_width/1.618))

sizes = [16, 32, 64, 128, 256]
experiments = ['SparseLets_' + '%0.3d' % size for size in sizes] # ['testing_vanilla_016', 'testing_vanilla_032', 'testing_vanilla_064', 'testing_vanilla_128', 'testing_vanilla']
experiments[-1] = 'SparseLets'
databases = ['serre07_distractors'] * len(experiments)
labels = [str(size) for size in sizes]
fig, a, ax = plot(fig=fig, mps=mps, experiments=experiments, databases=databases, 
                  labels=labels, scale=True)    
if dofig: 
    FORMATS = ['pdf', 'eps']
    for ext in FORMATS: fig.savefig(mps[0].pe.figpath + 'SparseLets_B.' + ext)
# Out:
# Overwriting test/experiment_fig-sparselets.py

# %%
import os
#print figpath
cmd = 'python test/experiment_fig-sparselets.py ' + figpath
os.system(cmd)
# %run test/experiment_fig-sparselets.py
# Out:
# INFO:SparseEdges: > computing edges for experiment SparseLets_016 with database serre07_distractors
# INFO:SLIP:There is no imagelist, creating one: [Errno 2] No such file or directory: '.mat/SparseLets_016_serre07_distractors_images.pickle'
# INFO:SLIP: > setting up image list for serre07_distractors
# INFO:SparseEdges: >> There is no edgeslist: [Errno 2] No such file or directory: '.mat/edges/SparseLets_016_serre07_distractors_edges.npy'
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn38.jpg[3, 19, 201, 217].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn38.jpg[3, 19, 201, 217].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mda_art545.jpg[149, 165, 95, 111].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mda_art545.jpg[149, 165, 95, 111].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mda_art1084.jpg[28, 44, 15, 31].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mda_art1084.jpg[28, 44, 15, 31].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fda_A673062.jpg[238, 254, 197, 213].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fda_A673062.jpg[238, 254, 197, 213].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bda_obj123.jpg[146, 162, 158, 174].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bda_obj123.jpg[146, 162, 158, 174].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_open20.jpg[21, 37, 204, 220].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_open20.jpg[21, 37, 204, 220].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_land317.jpg[61, 77, 14, 30].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_land317.jpg[61, 77, 14, 30].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mda_archi233.jpg[18, 34, 7, 23].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mda_archi233.jpg[18, 34, 7, 23].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj51.jpg[152, 168, 59, 75].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj51.jpg[152, 168, 59, 75].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj296.jpg[156, 172, 83, 99].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj296.jpg[156, 172, 83, 99].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bda_art1263.jpg[222, 238, 38, 54].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bda_art1263.jpg[222, 238, 38, 54].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bda_room9.jpg[147, 163, 41, 57].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bda_room9.jpg[147, 163, 41, 57].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj345.jpg[167, 183, 140, 156].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj345.jpg[167, 183, 140, 156].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj57.jpg[216, 232, 136, 152].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj57.jpg[216, 232, 136, 152].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bda_int30.jpg[49, 65, 50, 66].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bda_int30.jpg[49, 65, 50, 66].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj257.jpg[46, 62, 203, 219].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj257.jpg[46, 62, 203, 219].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_nat895.jpg[110, 126, 106, 122].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_nat895.jpg[110, 126, 106, 122].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn115.jpg[234, 250, 96, 112].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn115.jpg[234, 250, 96, 112].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bdn_text17.jpg[193, 209, 64, 80].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bdn_text17.jpg[193, 209, 64, 80].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_room425.jpg[16, 32, 197, 213].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_room425.jpg[16, 32, 197, 213].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mdn_text119.jpg[106, 122, 176, 192].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mdn_text119.jpg[106, 122, 176, 192].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_land56.jpg[179, 195, 7, 23].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_land56.jpg[179, 195, 7, 23].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn18.jpg[139, 155, 196, 212].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn18.jpg[139, 155, 196, 212].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bda_room141.jpg[52, 68, 219, 235].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bda_room141.jpg[52, 68, 219, 235].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_nat1251.jpg[72, 88, 102, 118].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_nat1251.jpg[72, 88, 102, 118].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn190.jpg[213, 229, 103, 119].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn190.jpg[213, 229, 103, 119].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn180.jpg[135, 151, 129, 145].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn180.jpg[135, 151, 129, 145].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_land11.jpg[129, 145, 65, 81].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_land11.jpg[129, 145, 65, 81].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj112.jpg[138, 154, 1, 17].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj112.jpg[138, 154, 1, 17].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn28.jpg[208, 224, 176, 192].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn28.jpg[208, 224, 176, 192].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bdn_nat846.jpg[219, 235, 62, 78].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bdn_nat846.jpg[219, 235, 62, 78].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj2.jpg[156, 172, 51, 67].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj2.jpg[156, 172, 51, 67].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bda_art1156.jpg[164, 180, 137, 153].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bda_art1156.jpg[164, 180, 137, 153].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bdn_text23.jpg[211, 227, 16, 32].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bdn_text23.jpg[211, 227, 16, 32].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bdn_text18.jpg[86, 102, 52, 68].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bdn_text18.jpg[86, 102, 52, 68].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn25.jpg[112, 128, 227, 243].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn25.jpg[112, 128, 227, 243].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_nat168.jpg[162, 178, 128, 144].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_nat168.jpg[162, 178, 128, 144].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_natu623.jpg[57, 73, 180, 196].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_natu623.jpg[57, 73, 180, 196].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn125.jpg[169, 185, 223, 239].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn125.jpg[169, 185, 223, 239].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mda_urb214.jpg[22, 38, 92, 108].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mda_urb214.jpg[22, 38, 92, 108].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_open21.jpg[138, 154, 94, 110].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_open21.jpg[138, 154, 94, 110].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj74.jpg[74, 90, 93, 109].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj74.jpg[74, 90, 93, 109].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bda_gre298.jpg[126, 142, 168, 184].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bda_gre298.jpg[126, 142, 168, 184].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fda_arnat64.jpg[81, 97, 36, 52].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fda_arnat64.jpg[81, 97, 36, 52].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fda_gre479.jpg[180, 196, 238, 254].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fda_gre479.jpg[180, 196, 238, 254].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mdn_N344067.jpg[16, 32, 33, 49].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mdn_N344067.jpg[16, 32, 33, 49].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fda_A683068.jpg[203, 219, 82, 98].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fda_A683068.jpg[203, 219, 82, 98].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_land135.jpg[141, 157, 119, 135].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_land135.jpg[141, 157, 119, 135].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_nat194.jpg[181, 197, 68, 84].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_nat194.jpg[181, 197, 68, 84].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj205.jpg[27, 43, 167, 183].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj205.jpg[27, 43, 167, 183].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mdn_natu169.jpg[26, 42, 208, 224].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mdn_natu169.jpg[26, 42, 208, 224].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bdn_natu379.jpg[76, 92, 135, 151].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bdn_natu379.jpg[76, 92, 135, 151].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mdn_land82.jpg[205, 221, 11, 27].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mdn_land82.jpg[205, 221, 11, 27].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_land12.jpg[117, 133, 79, 95].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_land12.jpg[117, 133, 79, 95].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mdn_N295008.jpg[29, 45, 183, 199].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mdn_N295008.jpg[29, 45, 183, 199].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj89.jpg[13, 29, 115, 131].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj89.jpg[13, 29, 115, 131].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_nat498.jpg[234, 250, 147, 163].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_nat498.jpg[234, 250, 147, 163].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mda_urb580.jpg[51, 67, 101, 117].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mda_urb580.jpg[51, 67, 101, 117].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fda_urb404.jpg[95, 111, 173, 189].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fda_urb404.jpg[95, 111, 173, 189].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_open2.jpg[69, 85, 112, 128].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_open2.jpg[69, 85, 112, 128].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn22.jpg[44, 60, 78, 94].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn22.jpg[44, 60, 78, 94].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn129.jpg[202, 218, 198, 214].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn129.jpg[202, 218, 198, 214].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn36.jpg[12, 28, 135, 151].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn36.jpg[12, 28, 135, 151].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mda_art1517.jpg[182, 198, 61, 77].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mda_art1517.jpg[182, 198, 61, 77].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mdn_sharp49.jpg[107, 123, 17, 33].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mdn_sharp49.jpg[107, 123, 17, 33].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fda_art36.jpg[148, 164, 139, 155].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fda_art36.jpg[148, 164, 139, 155].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fda_A487031.jpg[54, 70, 64, 80].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fda_A487031.jpg[54, 70, 64, 80].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bda_int46.jpg[158, 174, 230, 246].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bda_int46.jpg[158, 174, 230, 246].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mda_art1136.jpg[4, 20, 238, 254].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mda_art1136.jpg[4, 20, 238, 254].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj7.jpg[48, 64, 33, 49].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj7.jpg[48, 64, 33, 49].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn37.jpg[76, 92, 189, 205].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn37.jpg[76, 92, 189, 205].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mdn_N251013.jpg[54, 70, 111, 127].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mdn_N251013.jpg[54, 70, 111, 127].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mda_archi422.jpg[15, 31, 4, 20].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mda_archi422.jpg[15, 31, 4, 20].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mda_gre329.jpg[125, 141, 222, 238].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mda_gre329.jpg[125, 141, 222, 238].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bdn_nat915.jpg[185, 201, 43, 59].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bdn_nat915.jpg[185, 201, 43, 59].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn35.jpg[155, 171, 196, 212].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn35.jpg[155, 171, 196, 212].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bda_room165.jpg[108, 124, 69, 85].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bda_room165.jpg[108, 124, 69, 85].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fda_city49.jpg[125, 141, 192, 208].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fda_city49.jpg[125, 141, 192, 208].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bdn_natu676.jpg[201, 217, 78, 94].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Bdn_natu676.jpg[201, 217, 78, 94].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_text26.jpg[68, 84, 234, 250].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fdn_text26.jpg[68, 84, 234, 250].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn200.jpg[217, 233, 126, 142].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn200.jpg[217, 233, 126, 142].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mda_urb562.jpg[134, 150, 97, 113].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mda_urb562.jpg[134, 150, 97, 113].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fda_art1204.jpg[127, 143, 165, 181].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Fda_art1204.jpg[127, 143, 165, 181].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj144.jpg[117, 133, 57, 73].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hda_obj144.jpg[117, 133, 57, 73].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn44.jpg[2, 18, 184, 200].npy
# INFO:SparseEdges:Finished edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Hdn_objn44.jpg[2, 18, 184, 200].npy
# INFO:SparseEdges:Doing edge extraction of .mat/edges/SparseLets_016_serre07_distractors/Mda_archi56.jpg[231, 247, 17, 33].npy

# %% [markdown]
# ### Effect of parameters on edge extraction: filter parameters

# %%
import matplotlib
#matplotlib.rcParams.update({'font.size': 18, 'font.family': 'STIXGeneral', 'mathtext.fontset': 'stix'})
matplotlib.rcParams.update({'text.usetex': False})
# %matplotlib inline
#%config InlineBackend.figure_format='retina'
# %config InlineBackend.figure_format = 'svg' #raw_input('what figure format should we use? ') or default
#%config InlineBackend.rc = {'font.size': 14, 'text.usetex': False, 'savefig.dpi': 96, 'figure.figsize':  (13.0, 8.0), 'figure.subplot.bottom': 0.125}
import matplotlib.pyplot as plt

import numpy as np
np.set_printoptions(precision=4)#, suppress=True)
# http://ipython.org/ipython-doc/stable/config/extensions/autoreload.html
#%load_ext autoreload
#%autoreload 2

# where should we store the figures generated by this notebook
figpath = '../../CNRS/BICV-book/BICV_INT/BICV-sparse/'
figpath = './figures/'

# %%
# !pip install lmfit

# %%
# %%writefile test/experiment_fig-efficiency.py
"""

$ python experiment_fig-efficiency.py ../../CNRS/BICV-book/BICV-sparse/src/

rm -fr **/efficiency_* **/**/efficiency_* 

"""

import __init__
import numpy as np
from NeuroTools.parameters import ParameterSet
from SLIP import Image
from LogGabor import LogGabor
from SparseEdges import SparseEdges, plot
import sys
pe = ParameterSet('default_param.py')

threshold = None # classical plots
threshold = .15 # plot sparseness obtained when reaching this threshold

dofig = True
try:
    path = sys.argv[1]
except:
    path = '.'
    dofig = False
    
def init_pe(pe, N_X=pe.N_X, N_image=pe.N_image, N=pe.N):
    pe.seed = 123456
    pe.N_image = N_image
    pe.N_X = N_X
    pe.N = N
    pe.figpath = path + 'figures/'
    pe.edgefigpath = path + 'figures/edges/'
    pe.matpath = path + 'mat/'
    pe.edgematpath = path + 'mat/edges/'
    im = Image(pe)
    lg = LogGabor(im)
    mp = SparseEdges(lg)
    return mp

    
FORMATS = ['pdf', 'eps']
#FORMATS = ['png']
import matplotlib
matplotlib.use('Agg') 
#matplotlib.rcParams.update({'font.size': 18, 'font.family': 'STIXGeneral', 'mathtext.fontset': 'stix'})
matplotlib.rcParams.update({'text.usetex': False})

import matplotlib.pyplot as plt
fig_width_pt = 318.67085 # Get this from LaTeX using \showthe\columnwidth
inches_per_pt = 1.0/72.27               # Convert pt to inches
fig_width = fig_width_pt*inches_per_pt  # width in inches

fig, [[A, B], [C, D]] = plt.subplots(2, 2, figsize=(fig_width, fig_width), subplot_kw={'axisbg':'w'})


mps, experiments = [], []
v_B_sf = np.logspace(-.2, .2, 5, base=10, endpoint=True)*pe.B_sf
for B_sf in v_B_sf:
    pe = ParameterSet('default_param.py')
    pe.B_sf = B_sf
    mp = init_pe(pe)
    exp = 'efficiency_B_sf_' + str(B_sf).replace('.', '_')
    mp.process(exp)
    experiments.append(exp)
    mps.append(mp)

databases = ['serre07_distractors'] * len(experiments)
labels = ['%0.2f' % B_sf for B_sf in v_B_sf]
try:
    fig, A, ax = plot(mps=mps,
                      experiments=experiments, databases=databases, labels=labels, ref=2,
                      fig=fig, ax=A, color=[0., 1., 0.], threshold=threshold, scale=True)    
    A.set_xlabel(r'frequency bandwith $B_{sf}$')
    #A.set_yticks([0., 0.02, 0.04, 0.06])
except Exception, e:
    print('Failed to plot  with error : %s ' % e )
    
mps, experiments = [], []
v_B_theta = np.logspace(-.5, .5, 5, base=10, endpoint=True)*pe.B_theta
for B_theta in v_B_theta:
    pe = ParameterSet('default_param.py')
    pe.B_theta = B_theta
    mp = init_pe(pe)
    exp = 'efficiency_B_theta_' + str(B_theta).replace('.', '_')
    mp.process(exp)
    experiments.append(exp)
    mps.append(mp)

databases = ['serre07_distractors'] * len(experiments)
labels = ['%0.2f' % B_theta for B_theta in v_B_theta]
try:
    fig, B, ax = plot(mps=mps, 
                      experiments=experiments, databases=databases, labels=labels, ref=2, 
                      fig=fig, ax=B, threshold=threshold, scale=True, color=[0., 1., 0.])    
    B.set_xlabel(r'orientation bandwith $B_{\theta}$ (radians)')
    B.set_ylabel('')
    #B.set_yticks([0., 0.02, 0.04, 0.06])
    #B.set_yticklabels(['', '', '', ''])
except Exception, e:
    print('Failed to plot  with error : %s ' % e )
    
mps, experiments = [], []
v_n_theta = [6, 12, 24, 48]
for n_theta in v_n_theta:
    pe = ParameterSet('default_param.py')
    pe.n_theta = n_theta
    mp = init_pe(pe)
    exp = 'efficiency_n_theta_' + str(n_theta).replace('.', '_')
    mp.process(exp)
    experiments.append(exp)
    mps.append(mp)

databases = ['serre07_distractors'] * len(experiments)
labels = [str(n_theta) for n_theta in v_n_theta]
try:
    fig, C, ax = plot(mps=mps, 
                      experiments=experiments, databases=databases, labels=labels, ref=2, 
                      fig=fig, ax=C, threshold=threshold, scale=True, color=[0., 1., 0.])    
    C.set_xlabel(r'number of orientations $N_{\theta}$')
    #C.set_yticks([0., 0.02, 0.04, 0.06])
except Exception, e:
    print('Failed to plot  with error : %s ' % e )
    
mps, experiments = [], []
v_base_levels = [np.sqrt(2), np.sqrt(5)/2.+.5, np.sqrt(3), 2. , np.sqrt(5)]
#np.logspace(.25, 1.25, 5, base=2, endpoint=True)
for base_levels in v_base_levels:
    pe = ParameterSet('default_param.py')
    pe.base_levels = base_levels
    mp = init_pe(pe)
    exp = 'efficiency_base_levels_' + str(base_levels).replace('.', '_')
    mp.process(exp)
    experiments.append(exp)
    mps.append(mp)

databases = ['serre07_distractors'] * len(experiments)
labels = ['%0.2f' % (base_levels) for base_levels in v_base_levels]
labels[0] = r'$\sqrt{2}$'
labels[1] = r'$\phi$'
labels[3] = '2'
try:
    fig, D, ax = plot(mps=mps, 
                      experiments=experiments, databases=databases, labels=labels, ref=3, 
                      fig=fig, ax=D, threshold=threshold, scale=True, color=[0., 1., 0.])    
    D.set_xlabel(r'scale ratio')
    D.set_ylabel('')
    D.set_yticks([0., 1., 1.3])
    D.set_yticklabels(['0', '1', ''])
except Exception, e:
    print('Failed to plot  with error : %s ' % e )

for ax, label in zip([A, B, C, D], ['A', 'B', 'C', 'D']):
    ax.text(-.1, .95, label, transform=ax.transAxes, fontsize=12) #'('+label+')'
    ax.set_ylim([0., 1.6])
    ax.set_yticks([0., 1., 1.4])
    ax.set_yticklabels(["0", '1', ''])
    if label in ['B', 'D']: ax.set_yticklabels(['', '', ''])


#The parameter meanings (and suggested defaults) are::
#
#  left  = 0.125  # the left side of the subplots of the figure
#  right = 0.9    # the right side of the subplots of the figure
#  bottom = 0.1   # the bottom of the subplots of the figure
#  top = 0.9      # the top of the subplots of the figure
#  wspace = 0.2   # the amount of width reserved for blank space between subplots
#  hspace = 0.2   # the amount of height reserved for white space between subplots
fig.subplots_adjust(wspace=0.12, hspace=0.3,
                            left=0.125, right=0.98,
                            top=0.98,    bottom=0.12)
    
if dofig:
    for ext in FORMATS: fig.savefig(figpath + 'efficiency.' + ext)
fig.show()

# %%
import os
#%run experiment_fig-efficiency.py 
#print figpath
cmd = 'python test/experiment_fig-efficiency.py ' + figpath
_ = os.system(cmd)

# %% [raw]
# imagelist, edgeslist, RMSE = mp.process(exp='efficiency_B_theta_0_827881656201', name_database='serre07_distractors')
# print RMSE.shape
# RMSE /= RMSE[:, 0][:, np.newaxis]
# print RMSE[:, 0]
# print np.argmax(RMSE[0,:]<.3)
# print np.argmax(RMSE<.3, axis=1)
# print mp.oc

# %% [markdown]
# ### Perspectives: Better fits of the filters

# %% [markdown]
# Basically, it is possible to infer the best possible log-Gabor function, even if it's parameters do not fall on the grid

# %%
pe = ParameterSet('default_param.py')
im = Image(pe)
lg = LogGabor(im)
mp = SparseEdges(lg)

import scipy.optimize as opt

def twoD_Gaussian((x, y), x_pos, y_pos, theta, sf_0):
    FT_lg = lg.loggabor(x_pos, y_pos, sf_0=np.absolute(sf_0), B_sf=lg.pe.B_sf, theta=theta, B_theta=lg.pe.B_theta)
    return im.invert(FT_lg).ravel()

# Create x and y indices
x = np.arange(pe.N_X)
y = np.arange(pe.N_Y)
x, y = np.meshgrid(x, y)

#create data
x_pos, y_pos, theta, sf_0  = 23., 42., 142 * np.pi / 180., .01
x_pos, y_pos, theta, sf_0  = 23.6, 42.5, 2.34, .01
print sf_0
data = twoD_Gaussian((x, y), x_pos, y_pos, theta=theta, sf_0=sf_0)


# plot twoD_Gaussian data generated above
plt.figure()
plt.imshow(data.reshape(pe.N_X, pe.N_Y))
plt.colorbar()

# add some noise to the data and try to fit the data generated beforehand
data_noisy = data + 0.001*np.random.normal(size=data.shape)
# getting best match
C = mp.init(data_noisy.reshape(pe.N_X, pe.N_Y))
idx = mp.argmax(C)
initial_guess = [idx[0], idx[1], mp.theta[idx[2]], mp.sf_0[idx[3]]]
print 'initial_guess :', initial_guess, ', idx :', idx

popt, pcov = opt.curve_fit(twoD_Gaussian, (x, y), data_noisy, p0=initial_guess)

data_fitted = twoD_Gaussian((x, y), *popt)

extent = (0, pe.N_X, 0, pe.N_Y)
print 'popt :', popt, ', true : ', x_pos, y_pos, theta, sf_0
fig, ax = plt.subplots(1, 1)
ax.hold(True)
ax.imshow(data_noisy.reshape(pe.N_X, pe.N_Y), cmap=plt.cm.jet, 
          origin='upper', extent=extent)
_ = ax.contour(data_fitted.reshape(pe.N_X, pe.N_Y), 8, colors='w',
           origin='upper', extent=extent)

# TODO use a MLE to do the fit directly without scipy

# %% [markdown]
# ## some book keeping for the notebook

# %%
# %install_ext https://raw.githubusercontent.com/rasbt/python_reference/master/ipython_magic/watermark.py
# %load_ext watermark
# %watermark

# %%
# %install_ext http://raw.github.com/jrjohansson/version_information/master/version_information.py
# %load_ext version_information
# %version_information numpy, scipy, matplotlib, sympy

# %%
# CSS styling within IPython notebook
from IPython.core.display import HTML
def css_styling():
    styles = open("custom.css", "r").read()
    return HTML(styles)
css_styling()
